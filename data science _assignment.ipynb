# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# # load dataset

# %%
df =pd.read_csv("placement.csv")

# %%
df
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %% [markdown]
# # To  find minmun salary which s

# %% [markdown]
# # To find minmum salary in specialisation

# %%
df.groupby('specialisation')['salary'].min()
# Out:
# specialisation
# Mkt&Fin    200000.0
# Mkt&HR     200000.0
# Name: salary, dtype: float64

# %%
df.describe()
# Out:
#             sl_no       ssc_p       hsc_p    degree_p     etest_p       mba_p  \
# count  215.000000  215.000000  215.000000  215.000000  215.000000  215.000000
# mean   108.000000   67.303395   66.333163   66.370186   72.100558   62.278186
# std     62.209324   10.827205   10.897509    7.358743   13.275956    5.833385
# min      1.000000   40.890000   37.000000   50.000000   50.000000   51.210000
# 25%     54.500000   60.600000   60.900000   61.000000   60.000000   57.945000
# 50%    108.000000   67.000000   65.000000   66.000000   71.000000   62.000000
# 75%    161.500000   75.700000   73.000000   72.000000   83.500000   66.255000
# max    215.000000   89.400000   97.700000   91.000000   98.000000   77.890000
#
#               salary
# count     148.000000
# mean   288655.405405
# std     93457.452420
# min    200000.000000
# 25%    240000.000000
# 50%    265000.000000
# 75%    300000.000000
# max    940000.000000

# %%
df.isnull().sum()
#df.info()
# Out:
# sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %%
df.status
# Out:
# 0          Placed
# 1          Placed
# 2          Placed
# 3      Not Placed
# 4          Placed
#           ...
# 210        Placed
# 211        Placed
# 212        Placed
# 213        Placed
# 214    Not Placed
# Name: status, Length: 215, dtype: object

# %% [markdown]
# # To find how many people not placed

# %%
not_placed_list=df[df.status=='Not Placed']

# %%
not_placed_list
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 3        4      M   56.0  Central   52.0  Central   Science     52.00
# 5        6      M   55.0   Others   49.8   Others   Science     67.25
# 6        7      F   46.0   Others   49.2   Others  Commerce     79.00
# 9       10      M   58.0  Central   70.0  Central  Commerce     61.00
# 12      13      F   47.0  Central   55.0   Others   Science     65.00
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 198    199      F   67.0  Central   70.0  Central  Commerce     65.00
# 201    202      M   54.2  Central   63.0   Others   Science     58.00
# 206    207      M   41.0  Central   42.0  Central   Science     60.00
# 208    209      F   43.0  Central   60.0   Others   Science     65.00
# 214    215      M   62.0  Central   58.0   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status  salary
# ...

# %%
sample=df

# %%
sample.isnull().sum()
# Out:
# sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %%
sample['salary'].fillna(0,inplace=True)
# Out:
# C:\Users\HUAWEI\AppData\Local\Temp\ipykernel_21244\2628124827.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   sample['salary'].fillna(0,inplace=True)

# %%
sample
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
#sample['salary'].isnull().sum()
# Out:
# 0

# %%
# Reason

# %%
sample
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
degree=sample[sample['degree_t']=='Sci&Tech']['salary']

# %%
sp=sample[sample['specialisation']=='Mkt&HR']['salary']
sp
# Out:
# 0      270000.0
# 3           0.0
# 10     260000.0
# 12          0.0
# 14          0.0
#          ...
# 202    240000.0
# 203    260000.0
# 208         0.0
# 213    204000.0
# 214         0.0
# Name: salary, Length: 95, dtype: float64

# %%
sample.groupby('specialisation').mba_p.mean()
# Out:
# specialisation
# Mkt&Fin    62.825667
# Mkt&HR     61.586632
# Name: mba_p, dtype: float64

# %%
sample.groupby('specialisation').workex.count()
# Out:
# specialisation
# Mkt&Fin    120
# Mkt&HR      95
# Name: workex, dtype: int64

# %%
sample.groupby('specialisation')['etest_p'].sum()
# Out:
# specialisation
# Mkt&Fin    8986.26
# Mkt&HR     6515.36
# Name: etest_p, dtype: float64

# %% [markdown]
# # what kind of realation between mba_p and salary

# %%
sample.columns
# Out:
# Index(['sl_no', 'gender', 'ssc_p', 'ssc_b', 'hsc_p', 'hsc_b', 'hsc_s',
#        'degree_p', 'degree_t', 'workex', 'etest_p', 'specialisation', 'mba_p',
#        'status', 'salary'],
#       dtype='object')

# %%
def quanQual(sample):
        quan=[]
        qual=[]
        for col in df.columns:
            if(sample[ col].dtype=='O'):
                qual.append(col)
             # print('qual')
            else:
              #print('quan')
                quan.append(col)
        return quan,qual

# %%
quanQual(sample)
# Out:
# (['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary'],
#  ['gender',
#   'ssc_b',
#   'hsc_b',
#   'hsc_s',
#   'degree_t',
#   'workex',
#   'specialisation',
#   'status'])

# %%
quan,qual=quanQual(sample)

# %%
#df.groupby('specialisation')[df['salary'].sort_values(ascending=True)].min()
sample.groupby('specialisation')['salary'].min()
# Out:
# specialisation
# Mkt&Fin    0.0
# Mkt&HR     0.0
# Name: salary, dtype: float64

# %% [markdown]
# # To find relationship between mba_p and salary

# %%
corr=sample[quan].corr()

# %%
corr
# Out:
#              sl_no     ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# sl_no     1.000000 -0.078155 -0.085711 -0.088281  0.063636  0.022327  0.002543
# ssc_p    -0.078155  1.000000  0.511472  0.538404  0.261993  0.388478  0.538090
# hsc_p    -0.085711  0.511472  1.000000  0.434206  0.245113  0.354823  0.452569
# degree_p -0.088281  0.538404  0.434206  1.000000  0.224470  0.402364  0.408371
# etest_p   0.063636  0.261993  0.245113  0.224470  1.000000  0.218055  0.186988
# mba_p     0.022327  0.388478  0.354823  0.402364  0.218055  1.000000  0.139823
# salary    0.002543  0.538090  0.452569  0.408371  0.186988  0.139823  1.000000

# %%
corr['mba_p']['salary']
# Out:
# 0.1398227389261557

# %%
# the realation between mba and salary it is too low so nearly zero correlation 13% only correlate

# %%
coverance=sample[quan].cov()

# %% [markdown]
# # find salary above 500000

# %%
Above_50000_salary_list=sample[sample['salary']>500000]

# %%
Above_50000_salary_list
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 119    120      M   60.8  Central  68.40  Central  Commerce      64.6
# 150    151      M   71.0  Central  58.66  Central   Science      58.0
# 177    178      F   73.0  Central  97.00   Others  Commerce      79.0
#
#       degree_t workex  etest_p specialisation  mba_p  status    salary
# 119  Comm&Mgmt    Yes    82.66        Mkt&Fin  64.34  Placed  940000.0
# 150   Sci&Tech    Yes    56.00        Mkt&Fin  61.30  Placed  690000.0
# 177  Comm&Mgmt    Yes    89.00        Mkt&Fin  70.81  Placed  650000.0

# %%
sample['salary'].dtype
# Out:
# dtype('float64')

# %%
coverance
# Out:
#                  sl_no          ssc_p          hsc_p       degree_p  \
# sl_no      3870.000000     -52.641355     -58.106028     -40.413645
# ssc_p       -52.641355     117.228377      60.348373      42.897137
# hsc_p       -58.106028      60.348373     118.755706      34.819820
# degree_p    -40.413645      42.897137      34.819820      54.151103
# etest_p      52.556168      37.659225      35.461678      21.929469
# mba_p         8.102336      24.535952      22.555846      17.272020
# salary    24490.654206  901754.893936  763359.777657  465131.504238
#
#                 etest_p          mba_p        salary
# sl_no         52.556168       8.102336  2.449065e+04
# ssc_p         37.659225      24.535952  9.017549e+05
# hsc_p         35.461678      22.555846  7.633598e+05
# degree_p      21.929469      17.272020  4.651315e+05
# etest_p      176.251018      16.886973  3.842344e+05
# mba_p         16.886973      34.028376  1.262455e+05
# ...

# %%
coverance['etest_p']['mba_p']
# Out:
# 16.886973447076734

# %% [markdown]
# # anayo Test -Analysis of variance
# # it has two type one way(one independent) and two way(two independent)
# # it is used to analysis of more columns

# %%
from scipy.stats import stats
stats.f_oneway(sample['etest_p'],sample['mba_p'])
# Out:
# C:\Users\HUAWEI\AppData\Local\Temp\ipykernel_21244\1276089935.py:2: DeprecationWarning: Please import `f_oneway` from the `scipy.stats` namespace; the `scipy.stats.stats` namespace is deprecated and will be removed in SciPy 2.0.0.
#   stats.f_oneway(sample['etest_p'],sample['mba_p'])
# F_onewayResult(statistic=98.64487057324706, pvalue=4.672547689133573e-21)

# %%
#p<0.05 ------------>H0 there is no signficate
#here p value greater than signficate value so reject the null hypothesis  so accept alternative hypothesis 
#There is signficate different between etest_p,mba_p

# %% [markdown]
# # To find similarity between two columns
# # if find similarty between two columns using T-test .it used analysis of only two columns
# # it has two type independent (unpair) and dependent (pair)
# # unpair -different group with respective one column
# # pair - same group between different two column analysis

# %%
sample.head()
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
# 4      5      M  85.80  Central  73.60  Central  Commerce     73.30
#
#     degree_t workex  etest_p specialisation  mba_p      status    salary
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       0.0
# 4  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.0

# %%
from scipy.stats import  ttest_ind
degree=sample[sample['degree_t']=='Sci&Tech']['salary']
sp=sample[sample['specialisation']=='Mkt&HR']['salary']
ttest_ind(degree,sp)
# Out:
# TtestResult(statistic=2.692041243555374, pvalue=0.007897969943471179, df=152.0)

# %%
#p<0.05  consider reject the null hypothesis
#so her find the similarty between different group degree_t and specialisation but same value respective salary so we choose T-test indepentent unpair type method 
#finaly get p value less than significate value so we accept alternative hypothesis(There is similarity between sci&tech and MKt&HR

# %% [markdown]
# # covert normal distribution into standard distribution
# # different type unit convert into one type so easy to analysis

# %%
#convert normal distribution to standard distribution for salary
def stdnormalDist(sample):
    mean=sample.mean()
    std=sample.std()
    value=[i for i in sample]
    z_score=[((j - mean)/std) for j in value]
    sns.distplot(z_score,kde=True)

# %%
stdnormalDist(sample['salary'])
# Out:
# C:\Users\HUAWEI\AppData\Local\Temp\ipykernel_21244\3330982388.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(z_score,kde=True)

# %%
sns.distplot(sample['salary'])
# Out:
# C:\Users\HUAWEI\AppData\Local\Temp\ipykernel_21244\4129276869.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(sample['salary'])
# <Axes: xlabel='salary', ylabel='Density'>

# %% [markdown]
# # find the relation between specialisation  and other column like ssc_,hsc_p,mba_p,etest_p,salary

# %%
sns.pairplot(sample,hue="specialisation",palette='coolwarm')

# %%
sns.distplot(sample['salary'])
# Out:
# C:\Users\HUAWEI\AppData\Local\Temp\ipykernel_21244\4129276869.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(sample['salary'])
# <Axes: xlabel='salary', ylabel='Density'>

# %% [markdown]
# # probablites density function find different range between 600000 to 700000

# %%
def get_pro_density_fn(sample,start,end):
    from scipy.stats import norm
    import matplotlib.pyplot as plt
    ax=sns.distplot(sample,kde=True ,kde_kws={'color':'red'},color='green')
    plt.axvline(start,color='red')
    plt.axvline(end,color='red')
    sample1=sample
    sample_mean=sample1.mean()
    sample_std=sample1.std()
    print("mean&std",(sample_mean,sample_std))
    dist=norm(sample_mean,sample_std)
    values=[value for value in range (start,end)]
    probablities=[dist.pdf(value) for value in values]
    prob=sum( probablities)
    print("The area betwwen range ({}{}:{}".format(start,end,sum( probablities)))
    return prob

# %%
get_pro_density_fn(sample['salary'],600000,700000)
# Out:
# C:\Users\HUAWEI\AppData\Local\Temp\ipykernel_21244\4190257334.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax=sns.distplot(sample,kde=True ,kde_kws={'color':'red'},color='green')
# mean&std (198702.32558139536, 154780.92671560097)
# The area betwwen range (600000700000:0.004161320303283037
# 0.004161320303283037

# %%
from scipy.stats import  ttest_rel
deg=sample[sample['degree_t']=='Sci&Tech']['etest_p']
deg1=sample[sample['degree_t']=='Sci&Tech']['mba_p']
ttest_rel(deg,deg1)
# Out:
# TtestResult(statistic=5.0049844583693615, pvalue=5.517920600505392e-06, df=58)

# %%
#p value 5.517920600505392e-06
#p>0.05  consider accept the null hypothesis
#so her find the similarty  group degree_t( Sci&Tech)  but the different between the respective etest_p and mba_p so we choose T-test depentent pair type method 
#finaly get p value greater than significate value so we accept null hypothesis(There is not similarity between etest_p and mba_t

# %%
#which parameter highly correlate with salary
corr
# Out:
#              sl_no     ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# sl_no     1.000000 -0.078155 -0.085711 -0.088281  0.063636  0.022327  0.002543
# ssc_p    -0.078155  1.000000  0.511472  0.538404  0.261993  0.388478  0.538090
# hsc_p    -0.085711  0.511472  1.000000  0.434206  0.245113  0.354823  0.452569
# degree_p -0.088281  0.538404  0.434206  1.000000  0.224470  0.402364  0.408371
# etest_p   0.063636  0.261993  0.245113  0.224470  1.000000  0.218055  0.186988
# mba_p     0.022327  0.388478  0.354823  0.402364  0.218055  1.000000  0.139823
# salary    0.002543  0.538090  0.452569  0.408371  0.186988  0.139823  1.000000

# %%
#correlation talk about two column relationship
#here salary correlate ssc_p ----->netural 50%
#salary correlate hsc_p ---------->45% 
#salary correlate degree_p ---------->40% 
#salary correlate etest_p ---------->18% near to negative correlate
#salary correlate mba_p ---------->13% near to negative correlate

# %%
coverance
# Out:
#                  sl_no          ssc_p          hsc_p       degree_p  \
# sl_no      3870.000000     -52.641355     -58.106028     -40.413645
# ssc_p       -52.641355     117.228377      60.348373      42.897137
# hsc_p       -58.106028      60.348373     118.755706      34.819820
# degree_p    -40.413645      42.897137      34.819820      54.151103
# etest_p      52.556168      37.659225      35.461678      21.929469
# mba_p         8.102336      24.535952      22.555846      17.272020
# salary    24490.654206  901754.893936  763359.777657  465131.504238
#
#                 etest_p          mba_p        salary
# sl_no         52.556168       8.102336  2.449065e+04
# ssc_p         37.659225      24.535952  9.017549e+05
# hsc_p         35.461678      22.555846  7.633598e+05
# degree_p      21.929469      17.272020  4.651315e+05
# etest_p      176.251018      16.886973  3.842344e+05
# mba_p         16.886973      34.028376  1.262455e+05
# ...

# %%
#coverance talk about  two column difference ,here salary column large postive coverance  difference between  oyher column
#some columns like etest_p and mba_p postive coverance but small difference as well as mba_p mark coverance between other column small amount of coverance its near to zero coverance

# %% [markdown]
# # useful chart

# %%
sns.pairplot(sample,hue="gender",palette='coolwarm')

# %%
sns.pairplot(sample,hue="salary",palette='coolwarm')

# %%
sns.distplot(sample['salary'])
# Out:
# C:\Users\HUAWEI\AppData\Local\Temp\ipykernel_21244\4129276869.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(sample['salary'])
# <Axes: xlabel='salary', ylabel='Density'>
